# %%
from Data import parse_G2B
from search import tenderOpening
import pandas as pd

fromDay = [2015, 6, 20]
toDay = [2021, 6, 20]
biddingList, workList = parse_G2B('조경시설물설치공사업',fromDay, toDay)
# Out:
# ['2015', '11', '20']
# ['2016', '04', '20']
# ['2016', '09', '20']
# ['2017', '02', '20']
# ['2017', '07', '20']
# ['2017', '12', '20']
# ['2018', '05', '20']
# ['2018', '10', '20']
# ['2019', '03', '20']
# ['2019', '08', '20']
# ['2020', '01', '20']
# ['2020', '06', '20']
# ['2020', '11', '20']
# ['2021', '04', '20']

# %%
workList
# Out:
#     업무            공고번호   분류                                   공고명     공고기관  \
# 0   공사  20160515494-00  재입찰                    북천리 자전거도로(데크) 보수공사  강원도 횡성군
# 1   공사  20161221255-01   변경        병지방 산악자전거길 임도구간 안전 및 편의시설 설치공사  강원도 횡성군
# 2   공사  20161120276-00   일반                태기산 1200 고원힐링 관광지 조성공사  강원도 횡성군
# 3   공사  20170623842-00   일반            2017년 어답산(저수지 방면) 등산로 정비사업  강원도 횡성군
# 4   공사  20170435324-00   일반           제52회 강원도민체육대회 꽃탑(꽃조형물) 설치공사  강원도 횡성군
# 5   공사  20170336256-00   일반           2017년 운무산 등산로(능현사∼분기점) 정비사업  강원도 횡성군
# 6   공사  20171206303-00  재입찰                         호수길 안전난간 설치공사  강원도 횡성군
# 7   공사  20171132471-00   일반              안흥면 삼형제바위 등산로(강림방면) 조성사업  강원도 횡성군
# 8   공사  20171128845-00   일반                     산수골 등산로 안전시설 보강공사  강원도 횡성군
# 9   공사  20171009751-00   일반          2017년도 발교산 등산로(메밀밭골~정상) 정비사업  강원도 횡성군
# 10  공사  20170805262-00   일반                     산수골 등산로 우회노선 개설공사  강원도 횡성군
# ...

# %%
import pymysql
from sqlalchemy import create_engine

pymysql.install_as_MySQLdb()
import MySQLdb

engine = create_engine("mysql+mysqldb://root:845284@localhost/G2B", encoding = 'utf-8')
conn = engine.connect()

workList.to_sql('work', con = engine, if_exists='replace', index = False)
biddingList.to_sql('bidding', con = engine, if_exists='replace', index=False)
